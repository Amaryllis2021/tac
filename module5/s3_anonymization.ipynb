# %% [markdown]
# # Anonymisation de données

# %%
pip install faker
# Out:
# Collecting faker
#   Downloading faker-38.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in c:\users\aspng\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from faker) (2024.2)
# Downloading faker-38.2.0-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 4.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 4.2 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.0 MB 1.2 MB/s eta 0:00:02
#    -------------------------- ------------- 1.3/2.0 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.7 MB/s  0:00:01
# Installing collected packages: faker
# Successfully installed faker-38.2.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\aspng\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Imports

# %%
from pprint import pprint
from faker import Faker
from faker.providers import internet

# %% [markdown]
# "Faker is a Python package that generates fake data for you. Whether you need to bootstrap your database, create good-looking XML documents, fill-in your persistence to stress test it, or anonymize data taken from a production service, Faker is for you."
#
# https://faker.readthedocs.io/en/master/

# %% [markdown]
# "Use `faker.Faker()` to create and initialize a faker generator, which can generate data by accessing properties named after the type of data you want."

# %%
fake = Faker()

# %% [markdown]
# ## Créer un faux nom

# %%
print(fake.name())
# Out:
# Jennifer Weaver

# %%
# Il est possible de créer plusieurs faux noms, ici en français, avec une boucle.
fake_fr = Faker('fr_FR')
for _ in range(10):
    print(fake_fr.name())
# Out:
# Arnaude Le Berthelot
# Maurice Richard du Gomes
# Virginie Becker
# Nath Lacombe
# Georges Vidal
# Clémence de Dumas
# Arnaude Gallet
# André Chevallier
# Margaud Le Brun
# Étienne Giraud

# %%
# Même chose en néerlandais.
fake_nl = Faker('nl_NL')
for _ in range(10):
    print(fake_nl.name())
# Out:
# Lotte van Asten
# Jules van Enschot
# Olivia van Nus
# Lenn Tirie-van Ham
# Juul van der Pouw
# Rafael Noordijk-Stange
# Ayoub Everts
# Pippa Mater-de Grote
# Jolijn Sanders
# Sam Verboom

# %% [markdown]
# ## Créer une fausse adresse

# %%
# Pour créer une fausse adresse.
print(fake.address())
# Out:
# 25018 Estes Well Apt. 402
# East Ashlee, KY 26912

# %% [markdown]
# ## Créer une fausse adresse IP

# %%
fake.add_provider(internet)
print(fake.ipv4_public())
# Out:
# 64.134.129.188

# %% [markdown]
# ## Créer un faux profil complet

# %%
profile = fake_fr.simple_profile()
pprint(profile)
# Out:
# {'address': '14, rue de Courtois\n18479 Saint RenéVille',
#  'birthdate': datetime.date(1941, 6, 30),
#  'mail': 'veronique46@gmail.com',
#  'name': 'François-Gabriel Paris',
#  'sex': 'M',
#  'username': 'lesageemile'}
