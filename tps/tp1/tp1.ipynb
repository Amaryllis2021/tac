# %% [markdown]
# #Scraping: récupération des fichiers pdf du site du professeur Max de Wilde
#
# Dans ce notebook, nous créons un robot qui va scraper la page du professeur et récupérer le titre de tous les fichiers PDF et les stocker dans un fichier.
#
# Étapes 1 et 2 : OK
#
# #Imports

# %%
import re
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
from bs4 import BeautifulSoup
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# #Récupération de tous les 51 articles de la page d'accueil
#
# Étape 3 : OK

# %%
url = "https://max.de.wilde.web.ulb.be/camille"
try:
    response = requests.get(url, timeout=10, verify=False)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    
    print("Page Title:", soup.title.string if soup.title else "Camille")
    print("\nPage Text:")
    print(soup.get_text(strip=True, separator='\n'))
    
    print("\nLinks found:")
    for link in soup.find_all('a'):
        href = link.get('href', 'No href')
        text = link.get_text(strip=True) or 'No text'
        print(f"- {href}: {text}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: HTTPSConnectionPool(host='max.de.wilde.web.ulb.be', port=443): Max retries exceeded with url: /camille (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001F763308F10>, 'Connection to max.de.wilde.web.ulb.be timed out. (connect timeout=10)'))

# %% [markdown]
# #Amélioration du scraping et de enregistrement des 51 fichiers PDF dans un dossier sans erreurs de connexion SSL.

# %%
import requests
from bs4 import BeautifulSoup
import urllib3
import os
from urllib.parse import urljoin

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

articles = []


root_url = "https://max.de.wilde.web.ulb.be/camille"
folder = "camille_pdfs"
os.makedirs(folder, exist_ok=True)

try:
    response = requests.get(url, timeout=10, verify=False)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    for link in soup.find_all('a', href=True):
        href = link['href']
        if href.lower().endswith('.pdf'):
            pdf_url = urljoin(url, href)
            filename = os.path.join(folder, os.path.basename(href))
            print(f"Downloading: {pdf_url}")
            pdf_response = requests.get(pdf_url, verify=False)
            with open(filename, 'wb') as f:
                f.write(pdf_response.content)
            print(f"Saved: {filename}")
    print(f"\nAll PDFs saved to '{folder}' folder")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Error: HTTPSConnectionPool(host='max.de.wilde.web.ulb.be', port=443): Max retries exceeded with url: /camille (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001F7640BD350>, 'Connection to max.de.wilde.web.ulb.be timed out. (connect timeout=10)'))

# %% [markdown]
#  #APIs pour enrichir CAMille
#
#  Étape 4 : OK
#
#  #Imports

# %%
import json
import requests
import os
import requests
import PyPDF2
import re

# %%
API_TOKEN = "eRtDMbakSqTGKfQXRFOblqoLQSVLwkTf"  # https://www.ncdc.noaa.gov/cdo-web/token
headers = {"token": API_TOKEN}

for file in os.listdir("camille_pdfs"):
    if file.endswith('.pdf'):
        try:
            with open(f"camille_pdfs/{file}", 'rb') as f:
                text = " ".join([p.extract_text() for p in PyPDF2.PdfReader(f).pages])
        except Exception as e:
            print(f"Skipping {file}: {e}")
            continue
        
        dates = re.findall(r'\d{4}-\d{2}-\d{2}', text)[:3]
        locations = list(set(re.findall(r'\b[A-Z][a-z]+\b', text)))[:3]
        
        print(f"\n{file}: Dates={dates}, Locations={locations}")
        
        for date in dates[:1]:
            for loc in locations[:1]:
                r = requests.get(f"https://www.ncdc.noaa.gov/cdo-web/api/v2/data", 
                                headers=headers, params={"locationid": f"CITY:{loc}", 
                                "startdate": date, "enddate": date, "datasetid": "GHCND"})
                print(f"{loc} on {date}: {r.json() if r.ok else 'No data'}")
# Out:
# KB_JB92_1885-09-29_01-00002.pdf: Dates=[], Locations=['Cham', 'Maujan', 'Hundorts']

# %%
pip install PyMuPDF
# Out:
# Requirement already satisfied: PyMuPDF in c:\users\aspng\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.26.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\aspng\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import fitz  # PyMuPDF pour lecture des PDF
import os

# Chemin vers le dossier contenant les PDF
pdf_folder = "camille_pdfs"
pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith(".pdf")]

# Sélection du premier fichier PDF
pdf_path = os.path.join(pdf_folder, pdf_files[10])

# Ouverture et lecture du fichier PDF
doc = fitz.open(pdf_path)

# Extraction du texte
title = f"Titre du document : {pdf_files[10]}"
paragraphs = []

for page in doc:
    text = page.get_text()
    paragraphs.append(text.strip())

doc.close()

# Affichage
content = "\n".join(paragraphs)
print(title)
print("==================================")
print(content)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 9
#       6 pdf_files = [f for f in os.listdir(pdf_folder) if f.endswith(".pdf")]
#       8 # Sélection du premier fichier PDF
# ----> 9 pdf_path = os.path.join(pdf_folder, pdf_files[10])
#      11 # Ouverture et lecture du fichier PDF
#      12 doc = fitz.open(pdf_path)
#
# IndexError: list index out of range

# %% [markdown]
# #Nettoyage du texte à l'aide d'expressions régulières

# %%
# Suppression de tout ce qui se trouve entre parenthèses
clean_content = re.sub("\([^\)]+\)", " ", content)
# Suppression des espaces multiples
clean_content = re.sub("\s+", " ", clean_content)

print(content)
print("==================================")
print(clean_content)
# Out:
# 4 Ianvier 193S
# L/V L I B R E
# B E L G I Q U E
# EXTERIEUR
# *»•
# ' •*
# ALLEMAGNE
# LES AGRICULTEURS
# DE LA PRUSSE
# ORIENTALE
# DEMANDENT
# PROTECTION
# Kooiiicsbcrg. 3. — .-a chambre *!'*•
# priculture do la l'rus.s. Orientale u adres-
# sé au chancelier von Schleicher et au
# miuietro do l'Intérieur
# vou Braun, un
# télé-zrammo demandant oue des mesures
# soient prises immédiatement nour empê-
# cher rentrée en AHemanne des beurres,
# graisses, la-rd-s et orotluits analogues su-
# perflus
# UNE MOTION
# H I T L E R I E N N E
# CONTRE LES JOCKEYS ETRANGERS
# Berlin, 3. — Le parti hitlérien a dé-
# pOùô à la Dièto do Prusse une motion
# demandant que les étrangers ne puissent
# pi-us s'entraîner
# cn Allemagne
# comme
# jockey, é t a n t donné que (es postes les
# plus importants dans le sport
# hippique
# allemand sont occupés par des étrangers,
# nui font passer dans leur pays des gains
# énormes tandis que les jockeys allemands
# meurent de faim.
# ANGLETERRE
# UNE
# CARGAISON
# D'OR SUD-AFRI-
# CAIN
# A R R I V E
# A
# LONDRES
# Londres, 3. — Le paquebot
# tEdin
# tmrgh-Castle»,
# venant de l'Afrique du
# 6ud, est arrivé à Southampîon avec un
# chargement d'or évalué à 1,3G_.,000 livres
# •ter lin g.
# IRLANDE
# LES ELECTIONS
# CENERALES
# SONT FIXEES AU 24 JANVIER
# Dublin. 2 . — Lo Dail a été dissous ce
# fcoir.
# LI sera procédé à des élections géné-
# rales le 24 ianvier.
# La plus grande animation règne au-
# jourd'hui en Irlande à la suite de l'an-
# nonce do la dissolution du Dail. La cam-
# pagne électorale, qui va commencer im-
# médiatement,
# sera
# probablement
# l'une
# des plus durement disputées dans l'his-
# toire de l'Etat libre. Il est h peu près
# certain que l'un des points
# principaux
# du programme de M. de Valera sera la
# séparation complète do l'Etat
# libre du
# Conimomvealth britannique.
# HONGRIE
# LA SITUATION
# FINANCIERE
# EST
# DEFICITAIRE
# Budapest. 2. — La situation
# finan-
# cière de la Hongrie sera exposée par le
# ministre dos Finances à la session du
# comité financier de la S. D. N . , qui se
# réunira le 9 janvier à Genève.
# On estime à 140 millions de pengoes
# ifle pengoe vaut environ ti franes) lo dé-
# ficit budjiétairo probable de l'année eu
# cours. Le eouvernement hongrois espère
# obtenir par l'entremise do la S. D. N. un
# -ftliègemeut de 50 millions de pengoes sur
# Je service de sa dette extérieure, oui ab-
# sorbe plus de cent millions de pen noce
# Des
# mesures
# unilatérales
# apparaissent
# inévitables ei les créanciers ne consen-
# t e n t pas uue réduction des intérêts et
# d e s annuités.
# Pour alléger la charge estimée à 116
# (millions do pengoes, provenant des ver-
# sements dus aux Etats successeurs de la
# monarchie austro-honzroisfl pour les re-
# traites des fonctionnaires originaires da
# territoires détaches do la Hongrie, on
# envisage le versement forfaitaire do 5Û
# miillions pendant
# cinquante ans. à des
# compagnies
# d'assurance
# oui se charge-
# raient de cette opération. On sonne éga-
# lement à un emprunt intérieur gatré par
# des arriérés d'impôts, mais on a quelque
# doute sur le succès qu'il pourrait avoir.
# fUn échec mettrait en tout cas en ieu la
# popularité du cabinet. Aucune mesure ne
# eera arrêtée avant le voyage du ministre
# des Finances à Genève.
# ROUMANIE
# PLUS DE DEUX
# CENTS
# COMMUNISTES
# ARRETES
# < Bucarest. 3. — Des arrestations mas-
# sives de communistes ont eu Heu dans
# t o u t le pays. En deux jours. 160 commu-
# nistes ont été appréhendés dans la capi-
# tale et une centaine en province
# notam-
# ment à Jassv et à Cliisinau.
# SUISSE
# LA
# REORGANISATION DE LA
# BANQUE
# D'ESCOMPTE
# SUISSE
# Berne, 2. — On mande de Genève à
# l'Agence Télégraphique Suisse :
# Les représentants des principaux grou-
# pes intéressés à la
# Banque d'Escompte
# Suisse à Genève, c'est-à-dire : la Con-
# fédération, la
# Caisse dc3 Prêts de la
# Confédération Suisse, les banques canto-
# nales ot les grandes banques se siiot réu-
# nis sous la présidence du Dr Jïaehmann,
# président de la direction générale de la
# Banaue
# Nationale Suisse, pour
# étudier
# le plan de réorganisation définitive de
# la Banque d'Escompte Suisse. Un accord
# de principe a é t é réalisé sur on plan
# prévoyant la .4duct_on du capital ordi
# naire, la transformation du capital pri
# Tilégié en capital ordinaire et la con
# Tersion d'une part i i r W t a u t e de certains
# groupes de créances, notamment do la
# Confédération et des bniiqucs cantonales
# en capital-actions. Tl est prévu également
# nn nouveau
# concou rs dp la place de
# Genève.
# LE
# CONSEILLER
# SOCIALISTE
# N l -
# COLLE EN LIBERTE
# PROVISOIRE
# Genève, 3. — Sur la vue d'un rapport
# adressé Par le chef do la clinique géné-
# rale de 1 hôpital cantonal, le juge fédéral
# a ordonnera nusG en liberté provisoire de
# M. Léon Nicolle, conseiller national-socia-
# liste, arrêté ï\ la mute des événements
# meurtriers dit 9 novembre, h Genève. Il
# sera autorisé à séjourner à Genèvo jus-
# qu'à samedi pour mettre MM affaires en
# ordre. Tl devra ensuite ga^nor la station
# de Montagne de Leyain.
# U résulte, en effet, du rapport que
# l'état de santé de M. Nicolle nécessite
# un séjour à la montagne.
# ITALIE
# POUR LA MODE
# I T A L I E N N E
# Rome. 2. — Un projet de loi soumis à
# l'approbation du Parlement crée, à Tu-
# rin, un Institut de la mode, ayant une
# personnalité juridique et dont lo capital
# initial est de 2.030,000 lires. Une expo-
# sition permanente
# et deux
# expositions
# saisonnières mettront en évidence W as-
# pects
# ehnncnnnts et capricieux
# de la
# mode. Le but qu'on se propose est évi-
# demment
# d'essaver
# d'affranchir
# l'Italie
# de la tutelle étrangère et de répandre
# la mode italienne à travers le monde.
# .Rien h dîrp sur ce pr ocra m me» qui entre
# normalement dans le cadre
# économique
# d'une
# nation
# UN ACCORD AVEC LA
# ROUMANIE
# RELATIF
# AUX ECHANGES
# COM-
# MERCIAUX.
# Rome, 3. — Un accord provisoire con-
# cernant le paiement des échanges com-
# merciaux entre l'Italie et la Roumanie
# a été signé à Rome. Cet accord, qui est
# applicable à partir du 1er janvier et dont
# la durée n'est qne d'nn mois, doit
# for-
# mer, dnns l'esprit des parties contrac-
# tantes, la base d'un accord définitif.
# INDES ANGLAISES
# NOUVEAUX
# DESORDRES
# ENTRE
# MUSULMANS ET ARABES
# A TIZARA
# Londres. 3. - - O n mande d'Alwar à
# l'Agence
# Reuter:
# De nouveaux désordres sont signalés à
# Tizara, la vieille capitale de l'Etat d'Al-
# war. Une foule do Musulmans o n t atta-
# qué et pillé des boutiques et des maisons
# hindoues. Les troupes fédérales envoyées
# de Kishengnrb n'ont pu arriver à temps
# pour prévenir les désordres.
# Un certain malaise règne
# dans les Balkans
# UNT P R O J E T D'UNION
# D O U A N I E R E
# A U R A I T E T E S O U M I S A L'ALBA-
# N I E P A R L ' I T A L I E
# Londres, 2. — D a n s les m i l i e u x po-
# litiques anglais, on dit q u e le gou-
# v e r n e m e n t de T i r a n a
# a u r a i t porté n
# la c o n n a i s s a n c e d e certaines puissan-
# ces u n e proposition d'union
# d o u a n i e r ?
# qui lui a u r a i t été soumise p a r l'Italie
# en échange d ' u n e assistance
# financiè-
# re. On considère q u e cette
# c o m m u n i -
# cation semble établir q u e cette
# offre,
# si ello a été faite, n ' a p a s , du m o i n s
# jusqu'à nouvel odre, été acceptée. Cet-
# te attitude, dit-on, est v i v e m e n t a p p r é
# ciée à L o n d r e s , où l'on n e se dissi-
# mule p a s q u e l'acceptation a u r a i t été
# de
# n a t u r e
# à
# e n t r a î n e r
# de
# sérieuses
# complications d a n s les B a l k a n s .
# COURS ET CONFÉRENCES
# La question
# des contingentements
# Mardi soir, à la sertion d'économie poli
# tiiiua de la Chambre de commerce d-1 Br.i
# xelles. a eu lieu la suite de la discussion de
# la conférence laite le 6 décembre par M. le
# sénateur -Démets _.ur la question des contin
# Reniements.
# fl-ippelons que la plupart des
# membres présents à cette première séance
# s'étaient prononcés pour une large politique
# de libre-échange.
# M. Bovy n, premier orateur Inscrit, mardi
# s'atiacJie a démontrer que la Belgique doit
# pratiquer une
# politique
# libre-échangiste,
# écartant résolument toute tentative de ton-
# Unièmement, quelles Q-ie soient les mesures
# -i.. restriction priso* ailleurs. L<e contingente-
# ment esi, en ctïet, plu* dangereux qne le
# mal auquel li veut remédier. En l-Vance. par
# exemple, de 1029 A 193-'. les exportations ont
# baissé de 52 p. c.. tandis que les importa-
# tions n'ont diminué que de ____. p. c. D'autre
# part, la balance commerciale entre la Bel-
# gique et la Franc© s'est améliorée en 1932 k
# notre avantage, malgré les dious de doua-
# ne très élevés et les contingentements de no-
# tre voisine. Les contingentements ne rédui-
# sent pas le cJ-ômajrp; des
# cas d'espèce ne
# peuvent les JuMili-rj
# retroite_.se de notre
# marché Intérieur ne Justifie pas non plus
# une protection
# exceptionnelle. En ce qui
# conclue la grande Industrie. 11 est indis-
# pensable d'organiser une saine concurrence
# protégeant les consommateurs contre l'éco-
# nomie concertée ou dirigée, qui n'a pas d'é
# gard pour .es prix. En conclusion. M. Ba
# vyn préconise la suppression des contlnjeeu
# tements. l'abandon des activités
# lmproduc
# ttves (ia culture du blé. par exemple., la di-
# minution du cent des transports. l'extension
# de nos relations commerciales avec l'étran
# ger, l'abaissement de nos propres barrières
# douanières.
# XI. Aronstetn s'élève contre la « protection
# nisme éducateur • dont le but est de porter
# secours À une Industrie naissante détenu.'
# née. Dès qu'on entre dans la voie du pro-
# tectionnisme, impossible de s'arrêter et Von
# constate, en fin de compte, que l'on n'a rien
# protégé du tout et qu'au contraire on a pro
# fondement entravé l'action
# bienfaisante de
# la concurrence. Le contingentement est tou
# tofois nu (rein a l'avilissement des prix • in
# teneurs ». Mais même si l'on reconnaît l'U
# tllité d'une économie Internationale concer-
# tée, ce qui sera peut-être le programma de
# demain, on doit admettre que le contingen-
# tement n'est qu'une forme particulière de
# protection, nuisible, impuissante h atteindre
# le but poursuivi.
# M. Renier, enrjile. désirerait qu'on proté
# geAt efficacement l'Industrie de la chaussure
# et qu'en tout cas la marque d'origine fût
# imprimée sur la marchandise. Le contingen-
# tement est Ici. dit-il, tout indiqué. Nous ne
# pouvons, momentanément.
# laisser
# écraser
# nos industries nationales et s'accentuer le
# chômage Au reste, plus aucun pays ne res-
# pecte à l'heure actuelle le principe sacro-
# saint du lihre-échange.
# M. Manjin estime que le cont i n gen f eme n
# est peut-être nuisible; mais la situation ne
# serait-elle pas plus dangereuse encore si l'on
# n'y recourait pas ? M. Lobet abonde dans
# le môme sens : nous ne pouvons nous livrer
# pieds et mains liés aux concurrents étran-
# gers, dont beaucoup ne peuvent même plus
# payer leurs achats faits eu Belgique. Quant
# à M. Michelet. président de la Chambre do
# commerce, il pense que tout homme à le
# • devoir » de gagner de l'argent pour vivre
# et que, dès lors, une seule question doit se
# poser A son esprit : le libre-échangn me fait-
# Il gagner do
# l'argent, le protectionnisme
# m'en fait-Il perdre,
# — et Inversement ?
# En fin de séance, M. Démets résume brie
# veinent les divers points de vue, reconnais-
# sant ave,- les uns que 1* lil-re-êchange est
# uno doctrine excellente, remarquant, avec le»
# autres que le contingentement est souvent
# uue question d'espèce et d'opportunité.
# Un stock d'un demi-million de lin en feu
# Les m a g a s i n s de a*. L. Desmet, à Oost-Roosebeke
# (près d
# C o u r t r a i ) , e n
# train d e brûler. Malgré les efforts des p o m p i e r s
# d e Cucrne
# et de
# W a e r e -
# Ohem, l e t f l a m m e s o n t a n é a n t i p o n r o n demi-mlllicn de lin.
# Les nouvelles
# entre la Chine el le Japon
# LE JAPON PROTESTE A GENEVE
# Genève, 3. — Le d i r e c t e u r d u b u r e a u
# j a p o n a i s de la S.D.N. a n n o n c e a u se-
# crétaire général qui d e p u i s ie 20 oc-
# tobre les t r o u p e s du g é n é r a l
# Ycliang
# H s u e
# L i a n g ont c o n s t r u i t d e s t r a n -
# chées a l l a n t do l'Est do l a ville
# d e
# Jehol j u s q u ' à S h n n H a i K o u a n ;
# d'au-
# tres t r a n c h é e s solides o n t été complè-
# t e m e n t o r g a n i s é e s a u x e n v i r o n s
# de
# Tien-Tsin, le long de la ligne
# Tien-
# T s i n - P o n k e o u .
# Bien équipées en m u n i t i o n s et en
# aviation, ces t r o u p e s o n t
# c o m m e n c é
# des actions offensives de s o n d a g e con-
# tre les t r o u p e s j a p o n a i s e s i t a n t d u cô-
# té de Jehol q u e d a n s l a région
# de
# Tien-Tsin et de P é k i n .
# l.a lettre du d i r e c t e u r du b u r e a u ja-
# ponais a été c o m m u n i q u é e a u x m e m -
# bres du conseil et de l'assemblée de
# la Société des N a t i o n s .
# L E C O M M A N D A N T E N C H E F J A P O -
# N A I S A D R E S S E U N E N O T E
# COM-
# M I N A T O I R E A U M A R E C H A L CHI-
# NOIS T C H A N G S U E H L I A N G .
# Tien-Tsin, 3. — L'agence Rengo an-
# n o n c e q u e lo g é n é r a l N a k a m u r a , com-
# m a n d a n t en chef d e s g a r n i s o n s japo-
# n a i s e s en C h i n e d u Nord, a
# adressé
# a u m a r é c h a l T c h a n S u e h L i a n g , u n e
# note
# rejetant
# s u r les Chinois la res-
# ponsabilité d e s i n c i d e n t s de Chnn liai
# K o u a n q u i a u r a i e n t
# c a u s é la m o r t
# d'un officier et do 2 soldats j a p o n a i s
# et p r o t e s t a n t contre l'invasion d u Je-
# hol p a r les t r o u p e s chinoises.
# Le général j a p o n a i s invite !e m a r é -
# chal T c h a n g S u c n L i a n g k faire ces-
# ser re qu'il considère comijie d e s pro-
# vocations.
# On annonce,
# d ' a u t r e
# p a r t q u e les
# t r o u p e s chinoises a y a n t fait s a u t e r u n
# pont de c h e m i n de fer p r è s de C h a n g
# ai K o u a n , les c o m m a n d a n t s des gar-
# n i s o n s
# é t r a n g è r e s se sont
# r é u n i s en
# conférence a u q u a r t i e r général
# japo-
# n a i s p o u r e x a m i n e r la situation.
# (On sait en effet, quo
# d e p u i s la
# guerro des Tîoxers. des t r o u p e s
# étran-
# gères s t a t i o n n e n t le long d u c h e m i n
# de fer de P é k i n a C h a n H a i K o u a n ) .
# V I V E
# E M O T I O N A
# W A S H I N G T O N
# L o n d r e s , 3. — On m a n d e de W a s -
# h i n g t o n à l'Agence
# R e u t e r q u e l'in-
# cident de Chan H a i K o u a n a
# c a u s é
# u n e vive émotion à
# W a s h i n g t o n et
# q u e
# M. S t i m s o n ,
# secrétaire
# d'Ktat,
# suit, dérlare-t-on. avec la p l u s g r a n d e
# a t t e n t i o n
# les d é v e l o p p e m e n t s
# d e la
# situation.
# L'opinion de M» Bénès
# sur la campagne allemande
# pour la revision des traités
# Les _ Lidove N o v i n y », j o u r n a l de
# P r a g u e , n o u s a p p o r t e n t le texte d ' u n
# i n t e r v i e w q u e
# M. Benès,
# m i n i s t r e
# des Affaires et i n g è r e s de Tchécoslo-
# v a q u i e , lui a d o n n é e . M. B e n è s 7 a
# parlé de l a question des dettes ainsi
# q u e du « r é v i s i o n n i s m e ». A ce pro-
# pos, il a déclaré :
# •
# Ce n'est cortainement pas u n service
# rendu à la paix ni un encouragement
# donné à la confiance internationale <juo
# de mener, au moment où se prépare u n
# engagement
# international
# de désarme-
# ment général, une campagne systémati-
# que de méconnaissance des engagements
# internationaux naguère assumés e t que
# de réclamer la revision par des essais
# d'intimidation ou par la préparation do
# divers faits accomplis.
# D ' a u t a n t
# plus
# grandes doivent
# être
# l'inquiétude et
# la méfiance quand on
# voit que certains efforts
# révisionnistes,
# dont on peut ne pas reconnaître et ap-
# prouver les mobiles tout en les compre-
# n a n t psvcholociquement.
# sont exploités
# S our des manœuvres
# tactiques
# préten.
# a n t à rendre les uns plus conciliants,
# k donner
# aux autres des
# espérances
# d ' a u t a n t
# plus
# funestes
# qu'elles
# sont
# irréalisables et font obstacle à l'entente
# entre voisins, à la coopération et nu
# calms rèelement des relations mutuelles.
# De semblables actions provoquent d'iné-
# vitables réactions. Les pavs anglo-saxons
# se montrent plus
# sensibles
# qu'aupara-
# vant aux menées qui menacent la paix
# et le statut international actuel.
# Tous les gouvernements français pour-
# suivent la même politique circonspecte,
# inclinant à tout ca qui peut
# faciliter
# et élargir
# l'entente
# internationale en
# conservant les bases sur lesquelles s'édi-
# fie la nouvelle Europe. C'est la mémo
# ligne que suit, en pleine union, la Pe-
# tite Entente qui. dans sa dernière con-
# férence à Belgrade a eu uno nouvelle
# occasion do manifester le caractère con-
# structif de sa politique. Elle a montré
# qu'elle reste le fidèle et vigilant gardien
# de la paix on Europe centrale et sud-
# orientale,
# pour
# faire
# front
# à tout ce
# nui troublerait cette paix.
# _ La Petite
# Entente
# reste
# simplement
# fidèle
# à sa
# politique de toujours,
# «'efforçant
# d'af-
# firmer ses droits propres et sa collabo-
# ration amicale avec t n u s j e s petits Etats,
# s'ils sont vraiment légitimes, dans cette
# partie du continent.
# I R L A N D E
# M. DE VALERA
# EXPOSE LES MOTIFS
# DE LA
# DISSOLUTION
# ( P a r téléph. spéc. P a r i s 1 h. m a t i n . )
# A propos de la dissolution de la Dail
# Eireaiin, on télégrapliie de Dublin que,
# recevant les représentants de la presse,
# M. De Valera a annoncé que la Dail
# Eireann a é t é dissoute et que les élec-
# tions générales auront
# lieu le 24 jnn-
# vier dans l'Etat libre. Le nouveau
# par-
# lement irlandais se réunira le 8 février.
# En même temps, le Gouverneur géné-
# ral de l'Etat
# libre d'Irlande. M. Buc-
# kley, a siiîné une proclamation
# annon-
# çant officiellement
# la dissolution de la
# Dail Eireann à partir de lundi. M. De
# Valera a expliqué que les adversaires de
# son gouvernement avaient créé un sen-
# timent de doute dans la confiance que
# l'élcctorat
# irlandais
# avait
# placé
# dans
# l'administration actuelle et que leur acti-
# vité politique faisait le plus grave préju-
# dice aux intérêts de la nation aussi bien
# dans les relations
# internationales que
# dans les affaires
# politiques. 11 a souli-
# cné que les relations entre le parti répu-
# blicain irlnndais et le labour partv avait
# été des plus heureux, mais 1] a reietê
# tous les blâmes sur le Sénat
# irlandais
# qui, dit-il, s'est constamment efforcé de
# mutiler les mesures mises en avant par
# le gouvernement ou retardé l'application :
# de propos délibéra.
# I
# Un brise glace russe s'échoue
# près des côtes du Spitzberg
# .Moscou, 3. — L'agence T a s s a n n o n -
# ce q u e le
# brise-glace « M a l y g u i n e »
# s'est é c h o u é à 3 k i l o m è t r e s des cotes
# d u
# Spitzberg.
# Le brise-glace - Sedov » parti à son
# secours, n'a p u r e l e v e r seul le . Ma-
# l y g u i n e » et u n second n a v i r e ' a quitté
# A r k h a n g c l
# p o u r a i d e r a u s a u v e t a g e .
# Le Brésil envoie
# des forces navales et aériennes
# dans les eaux colombiennes
# Rio-de-Janeiro, 3. — E n v u e d'assu-
# r e r l a n e u t r a l i t é d u Brésil
# d a n s le
# conflit e n t r e le P é r o u et l a Colombie,
# la p r e m i è r e
# division n a v a l e
# compre-
# n a n t u n croiseur,
# .rois
# contre-torpil-
# leurs et cinq h y d r a v i o n s , p a r t i r a de-
# m a i n à d e s t i n a t i o n de T a b a t i n g a .
# F R A N C E
# LA SUSPENSION DU RECRUTEMENT
# DES
# FONCTIONNAIRES
# ( P a r téléph. spéc. Paria 1 h. m a t i n . )
# D'après l'a Intransigeant » le décret
# suspendant le recrutement des fonction-
# naires atteindra de 4.000 à S.OOO per-
# sonnes, c'est-à-dire les élèves sortant des
# grandes écoles et qui se destinaient à
# faire leur carrière dans l'administration.
# Parmi eux,
# certains auront le nioven
# d'attendre, d'autres pourront risquer la
# ebance dans les concours que les néces-
# sités du recrutement n'auront pas sup-
# primé, d'autres enfin préféreront
# pour-
# suivre leur carrière dans l'industrie pri-
# vée.
# A L L E M A G N E
# LUDENDORFF VA-T-IL
# DEVOIR
# F E R R A I L L E R
# AVEC
# UN DEPUTE OCTOGENAIRE?
# Berlin, 3. — Une violente polémiquo
# s'est élevée entre le général Ludendorff
# et l'ancieu député nationaliste von 01-
# denburg, ami intime du président von
# Hindenburg,
# au sujet de la
# propriété
# de Neudeck offerte au Maréchal à l'oc-
# casion do son 80e anniversaire.
# Le général
# expose qu'en
# récompense
# de l'activité qu'il avait dépensée lors de
# l'achat de Neudeck, l'ancien député au-
# rait été -favoris» dans la répartition des
# fonds attribués à l'occasion des secours
# en faveur de l'agriculture des provinces
# de l'Est.
# L'ancien député _. adressé une lettre
# ouverte au général l'invitant à se ré-
# tracter et déclarant qu'il se considérait
# toujours soumis aux règles suprêmes qui
# ordonnent aux officiers de défendre leur
# honneur.
# L'opinion
# suit
# avec
# curiosité
# cette
# perspective de duel entre l'ancien
# quar-
# tier-maître général des armées impéria-
# les et celui qu'on appelle le c lion de
# l'Est » et qui a 79 ans.
# A V A N T
# DE SE REMETTRE
# A LA
# BIERE, LES ETATS-UNIS ONT EN-
# VOYE A MUNICH
# UNE COMMIS
# SION CHARGEE
# D'ETUDIER LES
# AVANTAGES
# ET LES
# INCONVE-
# NIENTS DE CETTE BOISSON.
# Berlin, 3. — Avant de se prononcer
# sur la levée de la prohibition de 1%
# bière, les autorités américaines se sont
# livrées à une enquête
# très minutieuse
# Elles ont même envoyé en
# Allemagne
# une commission spéciale présidée par un
# professeur de la
# Yale
# University qui
# avait pour mission d'étudier sur place
# la fabrication de la bière, sa contenance
# en alcool et les effets de sa consomma*
# tion sur l'organisme humain.
# Le professeur
# Yandell s'est rendu à
# Munich où il s'est mis en rapport avec
# les producteurs allemands et a visité assi-
# dûment 1(S erandes brasserie bavaroises
# pour juger de la capacité de consomma-
# tion de l'homme et des conséquences de
# la bière sur les buveurs.
# Les spécialistes munichois lui ont dé.
# claré que ces questions ne peuvent pas
# être résolue uniformément pour tout le
# monde mais que tout dépend du tenii>é_
# rament de chaque individu.
# Cependant le professeur Yandell vient
# de repartir pour l'Amérique avec la con-
# viction que la bière n'est pas une bois.
# son nuisible mais au contraire
# hienlai*
# santé pour la santé. Il est arrivé à cotte
# constatation qu'une tasse de café a le
# même effet
# qu'un verre de bière sur
# l ' o n a n i s m e et que par contre un cigare
# enivre davantage qu'un verre de bière.
# R U S S I E
# TROIS ANCIENS
# FONCTIONNAIRES
# INCULPES DE « SABOTAGE »
# SONT CONDAMNES A MORT
# Moscou, 3. — Dc l'Agence Tass :
# Le tribunal
# régional de
# Dnieprope-
# trovsk a condamné à mort trois anciens
# fonctionnaires pour sabotage de l'appro-
# visionnement en blé. Trois autres fonc-
# tionnaires ont é t é condamnés à 10 ans
# de prison et cinq autres à 8 ans.
# Lo Parquet a établi que les condamnés
# avaient
# dressé de faux
# procès-verbaux
# sur les amblavurcs et incitaient les So-
# viets ruraux k saboter
# l'approvisionne-
# ment du blé en fournissant des chiffres
# de récoltes réduits et en encourageant un
# battage du blé qui produisait dc grandes
# pertes de grain.
# P O L O G N E
# UNE PROTESTATION POLONAISE A
# LONDRES CONTRE
# DES RADIO-
# DIFFUSIONS
# BRITANNIQUES.
# Londres, 3. — L'ambassade polonaise
# a adressé au
# Foreigu Office une note
# protestant contre certains commentaires
# sur les relations de la
# Pologne
# avec
# d'autres Etats radiodiffusés
# pendant la
# nuit du
# Nouvel-An par la
# « British
# Broadcasting Company ».
# La note
# demande que des mesures
# soient prises pour empêcher
# l'utilisation
# de la radiodiffusion britannique pour des
# fins de propagande politique contre une
# nation
# amie.
# NORVEGE.
# LE GOUVERNEMENT MET L'EMBAR.
# GO SUR TOUTES LES EXPORTA-
# TIONS DE BONS ET DE COUPONS.
# Oslo, 3. — L'n ordre provisoire
# pris
# en conseil des ministres met l'embargo
# sur toutes les exportations de bons et de
# coupons payables soit eu couronne
# nor-
# végiennes, soit en devises étrangères.
# Les
# citoyens
# norvégiens
# habitant la
# Norvège et détenteurs de bons ne pour-
# ront en demander le paiement qu'en cou-
# ronnes norvégiennes.
# Cette mesure, qui sera mise immédia-
# tement en vigueur,
# s'appliquera
# aussi
# aux anciens
# titres de paiement,
# mais
# seulement
# pendant
# la période
# durant
# laquelle l'étalon or norvégien sera
# sus-
# pendu.
# Les titres de paiement possédés par
# les étrangers ne seront pas affectés par
# cette mesure, même dans le cas où le
# paiement
# devrait
# être
# transféré à un
# Norvégien.
# L'expulsion de l'abbé
# Gilles.
# C o n t r a i r e m e n t à ce q u ' u n e informa-
# tion de source a l l e m a n d e
# a v a i t an-
# noncé, a u c u n e d é m a r c h e
# d i p l o m a t i q u e
# n'a été faite a u p r è s d e M. H y m a n s ,
# a u sujet d e l'expulsion de l'abbé Gil-
# les.
# A u c u n e d é m a r c h e de ce g e n r e n'est
# p r é v u e a u m i n i s t è r e
# d e s
# Affaires
# é t r a n g è r e s , les faits relevés k charge
# tle l'abbé Gilles m o t i v a n t
# p l e i n e m e n t
# la m e s u r e dont il a été l'objet
# B U L G A R I E
# TRENTE-QUATRE
# COMMUNISTES
# ARRETES A SOFIA
# Sofia. 3. — La police a fait irruption
# dans une salle où se trouvaient
# réunis
# Jes délégués des organisations communis-
# tes régionales de Bulgarie
# Trente-quatre
# arrestations, dont
# celle
# d'un député ont été opérées.
# — U n désespéré à f r a m e r i e s . — De
# notre
# c o r r e s p o n d a n t
# :
# _
# •*»
# L u n d i
# soir, u n j e u n e o u v r i e r
# cor-
# d o n n i e r E m i l e Licnard, 17 a n s , habi-
# t a n t F r a m e r i e s , était allé e n course
# p o u r ses p a r e n t s . Q u a n d
# il
# r e n t r a
# chez lui, il m o n t a à sa c h a m b r e , s a n s
# m o t dire. P o u a p r è s , on e n t e n d i t u n e
# détonation. Le j e u n e
# h o m m e
# s'était
# tiré u n c o u p de fusil d a n s le ventre.
# 11 est m o r t m a r d i
# m a t i n
# s a n s
# a v o i r
# voulu diro p o u r q u o i il s'était t u é .
# — U n m e u r t r e à s e r a i n g . — De no-
# tre c o r r e s p o n d a n t :
# Mardi soir, à 17 h. 30, u n crime a
# été c o m m i s r u e M o r c h a m p s . Un sur-
# veillant de c h a r b o n n a g e , M. C h a r l e s
# Collard, Sgé dc !>3 a n s , d e m e u r a n t r u e
# Colson,
# m a r c h a i t
# p a i s i b l e m e n t
# d a n s
# cette artère, a c c o m p a g n é de M. J.-B.
# Haecq, q u a n d a r r i v é s r u e M o r c h a m p s
# en face du n u m é r o 82, u n coup de feu
# claqua. M. Collard, a t t e i n t d'une balle
# à la n u q u e , s'effondra,
# t a n d i s
# q u ' u n
# i n d i v i d u qu'on a v a i t v u l'instant d'a-
# v a n t c o n t o u r n e r u n attelage pour se
# d i s s i m u l e r
# derrière lui,
# p r e n a i t la
# fuite à la faveur de l'obscurité.
# L'enquête
# o u v e r t e p a r le
# c o m m i s -
# saire de police a établi q u ' u n
# o u v r i e r
# licencié, a v a i t m e n a c é l a victime de
# mort. Cet o u v r i e r a été interrogé. Le
# p a r q u e t a fait u n e descente.
# — B a g a r r e m e u r t r i è r e à T o n g r e s . —
# De n o t r e c o r r e s p o n d a n t :
# «
# Ce m a t i n , à 2 h. 20, trois c o n s o m m a -
# t e u r s d'un café de l'avenue de la Ga-
# re, à T o n g r e s , r e n t r a i e n t chez eux.
# A r r i v é s c n face d u b u r e a u téiéL.io-
# n i q u e de l a gare, ils furent
# a t t a q u é s
# p a r les n o m m é s
# TheJens J e a n , Wil-
# m a n s Chrétien et M a t h i e u
# Verb'eelen,
# d a n g e r e u x r e p r i s d e justice.
# D a n s l a b a g a r r e q u i
# s'en
# suivit,
# J a c q u e s Driesen, o u v r i e r peintre, âgé
# de 20 a n s , fut a t t e i n t à l'aine d'un
# c o u p de c o u t e a u et s'écroula, p e r d a n t
# du s a n g e n a b o n d a n c e .
# S c h e p e r s , de H e r d e r e n , r e ç u t
# u n
# coup d e couteau
# d a n s le dos. A ce
# m o m e n t , u n e patrouille d e la g e n d a r -
# merie de T o n g r e s s u r g i t et m i t fin
# à la lutte.
# "
# J a c q u e s Driesen décéda p e u a p r è s .
# Son
# c a d a v r e a été t r a n s p o r t é à
# la
# m o r g u e .
# T h e l e n s J e a n , W i l m a n s Chrétien et
# Mathieu Verbeelen o n t été arrêtés et
# écroués à la prison de Tongres. L a
# g e n d a r m e r i e de T o n g r e s a fait les con-
# s t a t a t i o n s
# d'usage.
# De g r a v e s p r é s o m p t i o n s p è s e n t s u r
# T h e l e n s . Les trois a s s a i l l a n t s
# étaient
# ivres. On a r e t r o u v é l ' i n s t r u m e n t d u
# crime : u n c o u t e a u à dépecer les la-
# pins.
# LES SPORTS
# CYCLISME
# PYNENB.URQ NE COURRA
# PLUS AVEC
# VAN
# KEMPEN.
# — La consternation
# e>st
# grande en Hollande parre que Pynennurg a
# écrit k plusieurs dii*<_ teurs de vélodrome
# <iu'il ne courrait pljs avec Van Kempen par
# r* «ju* - ils ont toujours «les querelle;. »
# (Peut-être Rraspenninj. sera-t-il le co-équipier
# do Pynenhurg comme ce lut le CSA dans
# les Six-Jours de BruxeJIes.tandlt, que Walsc-i
# fornieralt équipe avec Van Kempen.
# RILLAITD
# OHAMPIONNAT
# DE BELGIQUE
# CADRE —
# Anvers, le 3. — Mardi, a commencé au Bil-
# lard Palare, le Championnat de Belgique au
# cadre 45/8, Ci-apres les premiers M»ultat*s
# des poules éliminatoires :
# Poule C. — Moons (Anvers) 400 points en
# W reprise*. 17.39 moyenne, 69 plus forte sé-
# rie: Hanssens (Bruxelles), ?63 points, en 22
# reprises. 11.95 moyenne, 55 plis forte série.
# Poule B. — Ue Doncker (Anvers) 400 points
# en 20 reprises, '-'O moyenne, 62 plus forte se-
# rie ; Semai. .Bruxelles), 244 points en 19 re-
# prises, 12.84 moyenne. 57 pins forte série.
# Van Belle O. (Oand) W points en 16 re-
# prises, moye.nne 25. plus forte série 112, bat
# Demulder
# (Courtrai) 237 points en 15 re-
# pri:_es, moy. 15.80; série 85.
# Baltus (Uéffe). 400 points en 34 -reprises:
# moy. 11.78; série 74, hat Clayes (Gand), 301
# points en 34 reprises, moy. 8.85. série 53.
# OHAMPIONNAT DE
# BELGIQUE 45/2. -
# Voici les avant-dorn iers résultats de la pre-
# mière Joirnêe des poules éliminatoires pou-
# le B .Semai [Bruxelles) 400 points. 21 repri-
# se5. 19.04 moyenne, mi plus forte série Van
# Belle IGand); 331 points. 21 reprises, 15.75
# moyenne. 80 |.lu* forte série, poule c. Moons
# (Anvers -ton points 21 reprises i?04 mo em*
# 183 plut forte série, claeys (Oand) 194 pts
# M reprises 9.70 moyonne, 41 plus forte sé-
# rie.
# Chronique religieuse.
# LA CONSECRATION D E L ' A N N E E
# AU S A C R E - C Œ U R sera célébrée d a n s
# l'église
# Sainte-Gudule
# le vendredi 8
# janvier, à 17 h e u r e s pour les D a m e s
# et à 20 h. 30 pour les h o m m e s seule-
# m e n t
# Elle sera présidée p a r Son E m i n c n
# ce le c a r d i n a l Van Roye, archevêque
# •Je Malines.
# Les œ u v r e s
# religieuses, sociales et
# •le jeunesse, et tous les bons chrétiens
# sont
# i n s t a m m e n t
# priés
# d'assister
# à
# cette cérémonie religieuse et patrioti-
# que, afin qu'elle ait u n caractère vrai
# m e n t
# national et a t t i r e les bénédic-
# tions de Dieu s u r nos familles et s u r
# notre
# patrie.
# .IXHIRCHX CANOZTJQUX DES ECJ-ITS
# DU SFF.VITEUF. DE DIEU,
# EE PERE ADOLPHE PETIT.
# OE LA CO MF A ONZE S E JESUS.
# A BEAURAING
# La promesse
# de la "Vierge,,
# s'est accomplie
# Elle parle à chacun des vision-
# naires et ne se montrera plus...
# D e
# n o t r e
# correspondant, m a r d i le
# 3 j a n v i e r :
# C o m m e
# l'apparition
# l'a
# a n n o n c é
# lundi soir, elle a fait à c h a c u n d e s
# visionnaires u n e c o m m u n i c a t i o n
# dont
# la t e n e u r u n e fois c o n n u e à D e a u r a i n g
# a suscité u n e c o m p r é h e n s i b l e émotion.
# Lcs e n f a n t s
# s'étaient
# r e n d u s à la
# grotte, vers 6 h. 30, a u milieu
# d'une
# foule i n n o m b r a b l e , a c c o u r u e d e s coins
# les p l u s éloignés d u p a y s et m ê m e de
# l'étranger.
# On les vit s o u d a i n t o m b e r à g e n o u x
# e n s e m b l e s a n s p o u s s e r u n cri.
# De cette voix élevée q u i caractérise
# leur état d'exaltation
# ils
# récitèrent
# u n e dizaine d e chapelet p u i s se tu-
# ront soudain a u m ê m e
# m o m e n t
# U n e m i n u t e d e t e r r e u r
# p l a n a s u r
# la
# m u l t i t u d e
# agenouillée. La
# prière
# extatique
# r e p r i t
# ensuite
# pour
# cesser
# b r u s q u e m e n t p e u a p r è s
# L'interrogatoire a laissé u n e impres-
# sion considérable. Il y a v a i t plus d e
# cent m é d e c i n s
# présents.
# Voici
# les réponses q u e
# d o n n è r e n t
# s i m u l t a n é m e n t , m a i s s é p a r é m e n t , les
# cinq
# visionnaires.
# 1. Gilherte Voisin (13 a n s ) t
# —
# Elle m ' a dit tout
# s i m p l e m e n t
# « Adieu ! »
# £. Gilberte D e g e i m b r a (9 a n s ) . Elle
# m J. d i t :
# — « Je convertiri-i
# les
# pécheurs.
# Adieu »
# 3. Albert Voisin (11 a n s ) : « Elie
# m ' a d i t quelque chose qu'elle m ' a prié
# de n e p a s répéter et u n e a u t r e chose
# encore; m a i s j ' i g n o r e si je puis la ré-
# péter ».
# i. A n d r é e D e g e l m b r e ( U a n s ) . Elle
# m ' a dit :
# _ Je suis l a m è r e d e Dieu et la
# Reine des Cieux.
# P r i e z toujours !
# Adieu I »
# 5) F e r n a n d e Voisin (15 a n s ) :
# « Je n ' a i vu l a Vierge q u ' a p r è s les
# autres. Elle m ' a dit :
# — A i m e z - v o u s m o n fils .
# — Oui, ai-je répondu.
# — Et m o i , m'aimez-vous aussi î
# — Oui.
# — Sacrifiez-vous p o u r m o i !
# Telles sont d a n s leur
# impression-
# n a n t l a c o n i s m e les déclarations
# des
# enfants.
# "
# Le m o m e n t n'est p a s v e n u de les
# c o m m e n t e r .
# Contentons-nous de dire
# que
# l'énigme
# c o n t i n u e à peser
# p l u s
# lourde q u e j a m a i s . . .
# . * *
# — B e a u r a i n g en autos-cars de luxe.
# Dép. t o u s les j o u r s à 14 h.: 50 fr. aller
# et retour.Sté Gén. d e s Autos-cars, 40. r.
# l e Malines (face Hôtel Plaza).T.1764«0
# 64391-
# ***
# B e a u r a i n g e n a u t o c a r s . D é p a r t s ré-
# guliers à 14 h. — Sté T r a n s p o r t s Auto-
# mobiles J. I. C , 47, r u e d u Pont-Neuf.
# T. 17.21.69. P r i x (5 lr. aller et retour.
# 646s;
# — B e a u r a i n g
# e n a u t o c a r s . — Dé-
# p a r t t o u s ies j o u r s à 13 h. 30. — SU-
# P E R L U X E CARS. — 158, Bd A d o l p h e
# Max. Tél. 17.67.68 j u s q u e 11 h. d u soir.
# — P r i x aller et r e t o u r 50 fr. Réservez
# vos places.
# 6443C
# ***
# B e a u r a i n g . D é p a r t j o u r n a l i e r en au-
# tocar à 14 h.; prix aller et retour, 50 fr.
# National-Tours, 116 Bd Adolphe Max,
# à côté c i n é m a Plaza. Tél. 17.42.87.
# 6463
# U n
# l i v r e
# l e m a t l o n n e l
# Que se passe-t-il
# à
# B e a u r a i n g ?
# p a r le
# principal
# témoin, le
# I V M n i s l ri.iu-v
# U n
# joli
# v o l u m e
# de 48 pages avec
# i p h o t o s en hélio.
# E n vente parloul : a francs.
# Ed. R E X , Louvain. C.C. 1521 6t
# — U n motcycllste se t u e à W a v r e -
# Notre-Dame. — L u n d i soir, vers 5 h.,
# M. Jos. Dillen, 28 a n s , suivait k m o t i
# l'attelage de M m e veuve Vertommcii,
# d e m e u r a n t
# a u
# h a m e a u
# _ Hout*?
# Kruis » à Wavrc-Ste-Cathcrinc.
# Au
# coin de la chaussée do W a v r e et d e la
# route d e Berlaor, le motocycliste en-
# t r a en collision avec l'attelage. Il fut
# tué s u r le coup.
# Arts, Sciences, Lettres
# Le peintre Carrier-Belleuse >•.
# P i e r r e
# Carrier-Beiicnse,
# le
# p e i n t r e
# français q u i v i e n t d e m o u r i r à P a r i s
# des s u i t e s d'une, o p é r a t i o n à l'âne d e
# 81 a n s .
# M i M
# DECILE
# SORCL
# >'U7TERA
# LA CO-
# MEDIE
# FRANÇAISE
# LE Ur JANVIER 1934.
# — Paris, 3. — M. «Jean Mlstlar, wus-secrétai-
# re d'Etat aux Beaux-Arts, a reçu ce matin
# Mme Cécile Sorel et M. Emile Fabre, admt-
# QlstrateUT général de la Comédie Française.
# Malgré l'insistance de Mme Cécile Sorel. U
# a été Impossible de lui rendre sa liberté im-
# médiatement Mme Cécile Sorel pestera donc
# à la Comédie Française pendant toute l'an-
# née 1933. Elle sera nommée sociétaire hono-
# raire k partir du ler Janvier 1934 avec l'au-
# torisation de Jouer sur d'autres scènes.
# Devant les arguments ora'a fajt valoir 16
# sous-twrétalre
# d'Etat,
# et
# afin
# de ne p)
# Dit .as
# créer de précédent, qni pourrait nuire plus
# tard k d'autres sociétaires, Mme Cécie Sorel
# est revenue sur sa déterminai ion primitive
# et a renoncé k quitter immédiatement la Co-
# médie Française
# UNE
# CONFERENCE
# OU
# PROFESSEUH
# PICCARD AU HAVRE. — t,e Havre, 3. — Le
# profes'ieur
# Piccard
# s'embarquera
# pour les
# Etats-Unis demain mercredi i 23 beures Bit
# le i Cïiamplain »,
# Avant son départ, U assistera A i n dîner
# offert en son honneur par la Municipalité
# du Havre et il fera en la salle des fêtes une
# conférence sur ses audacieuses
# excursions
# dans la stratosphère.
# JOURNAL OFFICIEL
# du 4 Janvier ;
# INTIRIEUR. — Oablnat. — La croix de
# chevalier de l'Ordre de Léopold II est con-
# féwée A M. De Smedt ch., etief de bureau S
# l'administration
# provinciale de la Flandre
# orientale, a l'occasion de sa mise à la re-
# traite.
# Les palmes d'or de l'Ordre de la Couronne
# sont décernées a M. Boeyen J.. rôdacte-ir au
# ministère de nniérieur, 4 l'occasion de u
# mise h la retraite.
# Bourgmestres. —
# Démission. _- Nomina-
# tions. — La démission ofterte par M. Van
# Cauwelaert F., de s » fonctions de bourg-
# mestre d'Anvers est acceptée.
# M. Huyamans c. est nomma bourgmestre
# d'Anvers.
# M. Zimmermann H. ost nommé bourgmes-
# tre d'Eupen.
# > • m
# Pluies et tempêtes
# UNE VIOLBN T T E M P E T E A SOV**.
# F L E
# S U R
# L ' A N G L E T E R R E
# E T
# L ' I R L A N D E
# Londres, %. — U n e violente t e m p ê t e
# s'est abattue aujourd'hui sur la Man-
# che, le sud-ouest de l'Angleterre
# et
# l'Irlande. On signale de n o m b r e u x d*_>
# gâts, n o t a m m e n t
# dans le N o r t h a m p -
# tonshire, où la circulation est inter-
# rompue en différents
# endroits.
# Plu-
# sieurs automobiles ont été renversées
# par l'ouragan. Dans le nord de l'Irlan-
# de, Une forte pluie a causé des inon-
# dations sur u n e
# g r a n d e étendue,
# k
# Whitehead, la mer a s u b m e r g é et a en-
# d o m m a g é la voie ferrée.
# En mer, on signale plusieurs acci-
# denta d e la navigation et les bateaux
# de sauvetage ont dû secourir des bâti-
# ments en détresse.
# T a r d
# dans la soirée,
# on
# m a n d e
# q u ' u n e tempête d ' u n e
# violence extrê-
# me a régné dans la Manche. A Folkes-
# tone,
# le vent a atteint la vitesse d e
# 60 milles à l'heure. L'ouragan est ac-
# compagné de pluies
# torrentielles q u i
# rendent la visibilité difficile.
# E N E S P A G N E , L E
# GUADALÇUIVIR
# D E B O R D E E T CAUSE D E G R A V E S
# D E G A T S
# Séville, 3. — A la suite de pluies
# torrentielles, le niveau des e a u x
# d u
# Guadalquivir a m o n t é de façon inquié-
# tante. Le port est fermé i toute navi-
# gation. Plusieurs voiliers ont été s u b -
# mergés. Trois péniches ont été empor-
# tées par le courant.
# Dans la région,
# de nombreuses inondations se sont pro-
# duites. Les eaux ont totalement enva-
# hi le village de Triana, dont les habi-
# tants ont dû
# s'enfuir
# sans avoir le
# temps de rien sauver. La route de Las
# Erillas est complètement
# submergée.
# Par endroits, les e a u x atteignent plus
# d'un mètre de hauteur. Les bas quar-
# tiers de Séville ont été également inou-
# Une femme traverse l'Afrique en auto
# Il est rappelé encore une fols aux fi-
# dèles qui posséderaient des écrits du ser-
# viteur de Dieu.
# le l'ère Adolphe
# petit,
# qu'en vertu du droit canon l'évêque de
# leur diocèse leur fait une obligation erave
# qui peut même être accompagnée de pei-
# nes ecclésiastiques, de remettre ces écrits
# à leur évt>qii-> (*eux qui conn«|trai«nt de_*
# personnes retenant
# des écrits du Pèr»;
# Petit, sont oblifc'éa aussi d'en référer A
# leur évêque dans les formes du droit. Ceux
# enfin qui, par piété envers le serviteur do
# Pieu, tiennent k garder ses écrits pourront
# n"en livrer qu'une copie authentique. Ces
# écrits doivent être remis av__nt la fin du
# •oii de février.
# 9611
# M m e Eva Dic-k-scm, la j e u n e Suédois
# q u i vient d'accomplir, seule, l a tra-
# versée d e l'Afrique d n s u d a n n o r d e n automobile. P a r t i e d e Nairobi
# (Afri-
# q u e Anglaise) e'.le a t r a v e r s é l'Ouganda
# le n o r d d u Congo belge, le Congo
# français, le Cai eroun
# la Nigeria, U S a h a r a , où elle e n t à vaincre la nei-
# ge ei le sable, et f i n a l e m e n t l'Algérie. L a p h o t o U m o n t r e à P a r i s aveo le
# négrillon qu'elle a r a m e n é d n K e n y a .
# ==================================
# 4 Ianvier 193S L/V L I B R E B E L G I Q U E EXTERIEUR *»• ' •* ALLEMAGNE LES AGRICULTEURS DE LA PRUSSE ORIENTALE DEMANDENT PROTECTION Kooiiicsbcrg. 3. — .-a chambre *!'*• priculture do la l'rus.s. Orientale u adres- sé au chancelier von Schleicher et au miuietro do l'Intérieur vou Braun, un télé-zrammo demandant oue des mesures soient prises immédiatement nour empê- cher rentrée en AHemanne des beurres, graisses, la-rd-s et orotluits analogues su- perflus UNE MOTION H I T L E R I E N N E CONTRE LES JOCKEYS ETRANGERS Berlin, 3. — Le parti hitlérien a dé- pOùô à la Dièto do Prusse une motion demandant que les étrangers ne puissent pi-us s'entraîner cn Allemagne comme jockey, é t a n t donné que lo dé- ficit budjiétairo probable de l'année eu cours. Le eouvernement hongrois espère obtenir par l'entremise do la S. D. N. un -ftliègemeut de 50 millions de pengoes sur Je service de sa dette extérieure, oui ab- sorbe plus de cent millions de pen noce Des mesures unilatérales apparaissent inévitables ei les créanciers ne consen- t e n t pas uue réduction des intérêts et d e s annuités. Pour alléger la charge estimée à 116 , e n train d e brûler. Malgré les efforts des p o m p i e r s d e Cucrne et de W a e r e - Ohem, l e t f l a m m e s o n t a n é a n t i p o n r o n demi-mlllicn de lin. Les nouvelles entre la Chine el le Japon LE JAPON PROTESTE A GENEVE Genève, 3. — Le d i r e c t e u r d u b u r e a u j a p o n a i s de la S.D.N. a n n o n c e a u se- crétaire général qui d e p u i s ie 20 oc- tobre les t r o u p e s du g é n é r a l Ycliang H s u e L i a n g ont c o n s t r u i t d e s t r a n - chées a l l a n t do l'Est do l a ville d e Jehol j u s q u ' à S h n n H a i K o u a n ; d'au- tres t r a n c h é e s solides o n t été complè- t e m e n t o r g a n i s é e s a u x e n v i r o n s de Tien-Tsin, le long de la ligne Tien- T s i n - P o n k e o u . Bien équipées en m u n i t i o n s et en aviation, ces t r o u p e s o n t c o m m e n c é des actions offensives de s o n d a g e con- tre les t r o u p e s j a p o n a i s e s i t a n t d u cô- té de Jehol q u e d a n s l a région de Tien-Tsin et de P é k i n . l.a lettre du d i r e c t e u r du b u r e a u ja- ponais a été c o m m u n i q u é e a u x m e m - bres du conseil et de l'assemblée de la Société des N a t i o n s . L E C O M M A N D A N T E N C H E F J A P O - N A I S A D R E S S E U N E N O T E COM- M I N A T O I R E A U M A R E C H A L CHI- NOIS T C H A N G S U E H L I A N G . Tien-Tsin, 3. — L'agence Rengo an- n o n c e q u e lo g é n é r a l N a k a m u r a , com- m a n d a n t en chef d e s g a r n i s o n s japo- n a i s e s en C h i n e d u Nord, a adressé a u m a r é c h a l T c h a n S u e h L i a n g , u n e note rejetant s u r les Chinois la res- ponsabilité d e s i n c i d e n t s de Chnn liai K o u a n q u i a u r a i e n t c a u s é la m o r t d'un officier et do 2 soldats j a p o n a i s et p r o t e s t a n t contre l'invasion d u Je- hol p a r les t r o u p e s chinoises. Le général j a p o n a i s invite !e m a r é - chal T c h a n g S u c n L i a n g k faire ces- ser re qu'il considère comijie d e s pro- vocations. On annonce, d ' a u t r e p a r t q u e les t r o u p e s chinoises a y a n t fait s a u t e r u n pont de c h e m i n de fer p r è s de C h a n g ai K o u a n , les c o m m a n d a n t s des gar- n i s o n s é t r a n g è r e s se sont r é u n i s en conférence a u q u a r t i e r général japo- n a i s p o u r e x a m i n e r la situation. . V I V E E M O T I O N A W A S H I N G T O N L o n d r e s , 3. — On m a n d e de W a s - h i n g t o n à l'Agence R e u t e r q u e l'in- cident de Chan H a i K o u a n a c a u s é u n e vive émotion à W a s h i n g t o n et q u e M. S t i m s o n , secrétaire d'Ktat, suit, dérlare-t-on. avec la p l u s g r a n d e a t t e n t i o n les d é v e l o p p e m e n t s d e la situation. L'opinion de M» Bénès sur la campagne allemande pour la revision des traités Les _ Lidove N o v i n y », j o u r n a l ...

# %% [markdown]
# #Création d'un fichier avec le contenu de l'article

# %%
with open("../tp1/camille_example.txt", "w") as writer:
    writer.write(f"{title}\n\n{clean_content}")

# %% [markdown]
# #Utiliser Free OCR API (comme celle proposée par [OCR.space](https://ocr.space/ocrapi)) permet extraire automatiquement du texte à partir d’images, y compris des fichiers .png.
#
# Étape 5 : OK

# %%
import os
import fitz
import requests

os.makedirs("camille_images", exist_ok=True)
API_KEY = "K83927014588957"  # clé a demander sur OCR.space
for pdf in os.listdir("camille_pdfs"):
    if not pdf.endswith(".pdf"): continue
    doc = fitz.open(f"camille_pdfs/{pdf}")
    for i, page in enumerate(doc):
        for img in page.get_images(full=True):
            xref = img[0]
            pix = fitz.Pixmap(doc, xref)
            if pix.n < 5:
                pix.save(f"camille_images/{pdf}_{i}_{xref}.png")
            else:
                fitz.Pixmap(fitz.csRGB, pix).save(f"camille_images/{pdf}_{i}_{xref}.png")
            with open(f"camille_images/{pdf}_{i}_{xref}.png", "rb") as f:
                r = requests.post("https://api.ocr.space/parse/image",
                                  files={"file": f}, data={"apikey": API_KEY})
            print(pdf, i, "->", r.status_code)
# Out:
# KB_JB230_1892-08-07_01-0003.pdf 0 -> 200
# KB_JB230_1903-10-16_01-0002.pdf 0 -> 200
# KB_JB230_1913-07-05_01-0001.pdf 0 -> 200
# KB_JB258_1884-09-03_01-0003.pdf 0 -> 200
# KB_JB258_1894-12-09_01-0003.pdf 0 -> 200
# KB_JB258_1906-01-09_01-0002.pdf 0 -> 200
# KB_JB421_1899-05-15_01-00003.pdf 0 -> 200
# KB_JB421_1926-10-29_01-00002.pdf 0 -> 200
# KB_JB421_1950-04-15_01-00004.pdf 0 -> 200
# KB_JB427_1920-01-10_01-00004.pdf 0 -> 200
# KB_JB427_1933-01-04_01-00003.pdf 0 -> 200
# KB_JB427_1949-07-18_01-00008.pdf 0 -> 200
# KB_JB449_1846-05-30_01-00002.pdf 0 -> 200
# KB_JB449_1912-01-04_01-00003.pdf 0 -> 200
# KB_JB449_1947-08-29_01-00003.pdf 0 -> 200
# KB_JB494_1853-10-30_01-0002.pdf 0 -> 200
# KB_JB494_1922-09-28_01-0005.pdf 0 -> 200
# KB_JB494_1939-12-08_01-0004.pdf 0 -> 200
# KB_JB555_1836-02-08_01-00002.pdf 0 -> 200
# KB_JB555_1899-01-19_01-00003.pdf 0 -> 200
# KB_JB555_1940-03-01_01-00004.pdf 0 -> 200
# KB_JB567_1857-02-02_01-00003.pdf 0 -> 200
# KB_JB567_1892-01-03_01-00005.pdf 0 -> 200
# KB_JB567_1924-08-30_01-00003.pdf 0 -> 200
# KB_JB572_1850-03-15_01-00003.pdf 0 -> 200
# KB_JB572_1927-07-20_01-00005.pdf 0 -> 200
# KB_JB572_1950-06-07_01-00004.pdf 0 -> 200
# KB_JB638_1860-05-21_01-00002.pdf 0 -> 200
# KB_JB638_1902-12-20_01-00002.pdf 0 -> 200
# KB_JB638_1946-07-18_01-00003.pdf 0 -> 403
# KB_JB685_1894-05-14_01-0003.pdf 0 -> 403
# KB_JB685_1903-01-18_01-0002.pdf 0 -> 403
# KB_JB685_1913-06-07_01-0006.pdf 0 -> 403
# KB_JB729_1895-10-08_01-00003.pdf 0 -> 403
# KB_JB729_1927-11-15_01-00004.pdf 0 -> 403
# KB_JB729_1939-10-31_01-00006.pdf 0 -> 403
# KB_JB773_1918-11-30_01-00002.pdf 0 -> 403
# KB_JB773_1933-10-07_01-00007.pdf 0 -> 403
# KB_JB773_1950-07-22_01-00010.pdf 0 -> 403
# KB_JB835_1911-04-24_01-00004.pdf 0 -> 403
# KB_JB835_1930-04-08_01-00006.pdf 0 -> 403
# KB_JB835_1949-09-18_01-00004.pdf 0 -> 403
# KB_JB837_1886-12-28_01-00002.pdf 0 -> 403
# KB_JB837_1925-01-01_01-00003.pdf 0 -> 403
# KB_JB837_1950-12-01_01-00007.pdf 0 -> 403
# KB_JB838_1887-12-28_01-00003.pdf 0 -> 403
# KB_JB838_1911-08-03_01-00006.pdf 0 -> 403
# KB_JB838_1943-09-04_01-00002.pdf 0 -> 403
# KB_JB92_1860-02-09_01-00003.pdf 0 -> 403
# KB_JB92_1873-02-06_01-00002.pdf 0 -> 403
# KB_JB92_1885-09-29_01-00002.pdf 0 -> 403

# %% [markdown]
# Analyse du resultat : ces fichiers .png sont les articles de presse, car les fichiers PDF sont en réalité des images des articles scannés.

# %% [markdown]
# #Utiliser NCDC CDO web services API ( [NCEI CDO](https://www.ncei.noaa.gov/)) pour d’extraire automatiquement données de la meteo.

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

station_id = "GHCND:BE000065417"  # Bruxelles-Uccle
base_url = "https://www.ncei.noaa.gov/cdo-web/api/v2/data" 
api_token = "eRtDMbakSqTGKfQXRFOblqoLQSVLwkTf" #Clé a demander sur https://www.ncdc.noaa.gov/cdo-web/token

params = {
    'datasetid': 'GHCND',
    'stationid': station_id,
    'startdate': '2023-01-01',
    'enddate': '2024-01-01',
    'limit': 1000
}

headers = {'token': api_token}
resp = requests.get(base_url, headers=headers, params=params)
data = resp.json()

try:
    results = data['results']
    print(f"Données météo pour {station_id}:")
    for record in results:
        print(f"- {record['date']}: {record['value']} {record['datatype']}")
except KeyError:
    print("Aucune donnée disponible ou erreur de station")
# Out:
# Aucune donnée disponible ou erreur de station
