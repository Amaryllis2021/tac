# %% [markdown]
# TP4: Travail final
# Traitement automatique de corpus
# Auteur: Amarilis PEGO
#
# L´objectif du travail est d'utiliser un ensemble de bibliothèques Python pour analyser un corpus de médias afin d'extraire des informations sur la représentation des femmes dans la société. Les bibliothèques mentionnées, en particulier celles liées à la classification, sont particulièrement adaptées pour cette tâche.

# %%
import nltk
nltk.download('punkt') #Offre la tokenisation, la suppression des mots vides, le stemming/lemmatisation (via WordNetLemmatizer).
nltk.download('stopwords') #Fournit des listes de mots vides pour diverses langues.
nltk.download('wordnet') # Lemmatisation des listes de mots vides pour
nltk.download('omw-1.4') # pOUR LE WordNet DU NLTK 3.6+
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import nltk
#       2 nltk.download('punkt') #Offre la tokenisation, la suppression des mots vides, le stemming/lemmatisation (via WordNetLemmatizer).
#       3 nltk.download('stopwords') #Fournit des listes de mots vides pour diverses langues.
#
# ModuleNotFoundError: No module named 'nltk'

# %%
# Prétraitement du Texte
import nltk #Offre la tokenisation, la suppression des mots vides, le stemming/lemmatisation (via WordNetLemmatizer).
import PyPDF2 #Facilite le travail avec les documents PDF (potentiellement pour l'extraction de texte).
import unidecode # Normalise le texte en supprimant les accents et autres diacritiques.
import stopwords #Fournit des listes de mots vides pour diverses langues.
import string # Contient des fonctions de manipulation de chaînes (peut être utile pour nettoyer le texte).
import re # Permet le traitement de texte basé sur des expressions régulières.
import operator
import sys
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Prétraitement du Texte
# ----> 2 import nltk #Offre la tokenisation, la suppression des mots vides, le stemming/lemmatisation (via WordNetLemmatizer).
#       3 import PyPDF2 #Facilite le travail avec les documents PDF (potentiellement pour l'extraction de texte).
#       4 import unidecode # Normalise le texte en supprimant les accents et autres diacritiques.
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import sys

# Fonction pour installer un package
def install(nlk, package):
    try:
        import importlib
        importlib.import_module(package)
    except ImportError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Liste des packages à installer
packages = ['nltk', 'PyPDF2', 'unidecode', 'stopwords', 'string', 're', 'operator', 'pandas']

# Installation des packages
for package in packages:
    install(package)

print("Installation terminée !")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7, in install(package)
#       6     import importlib
# ----> 7     importlib.import_module(package)
#       8 except ImportError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'nltk'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#Analyse de Corpus :
import pandas #Gère les dataframes pour stocker et manipuler les données textuelles.
import yake #Implémente des algorithmes d'extraction de mots-clés (utile pour la modélisation de sujets).
import wordcloud #Crée des nuages de mots pour visualiser les fréquences des termes.
import seaborn #Fournit des fonctionnalités avancées de tracé statistique.
import pprint #Affiche les structures de données de manière lisible.
import scikitlearn #spécifiquement TfidfVectorizer, KMeans, PCA) :
import TfidfVectorizer #Crée des représentations TF-IDF des documents textuels.
import KMeans #Effectue le clustering k-means pour regrouper des documents similaires.
import PCA #Réduit la dimensionnalité pour la visualisation ou une analyse plus approfondie.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 #Analyse de Corpus :
#       2 import pandas #Gère les dataframes pour stocker et manipuler les données textuelles.
# ----> 3 import yake #Implémente des algorithmes d'extraction de mots-clés (utile pour la modélisation de sujets).
#       4 import wordcloud #Crée des nuages de mots pour visualiser les fréquences des termes.
#       5 import seaborn #Fournit des fonctionnalités avancées de tracé statistique.
#
# ModuleNotFoundError: No module named 'yake'

# %%
#Autres bibliotheqes 
import multiprocessing
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np
import yake
from wordcloud import WordCloud
from IPython.display import Image
import spacy
from spacy.lang.fr.examples import sentences
# !python -m spacy download fr_core_news_md
from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer
import seaborn as sn
from pprint import pprint
from sklearn.metrics import confusion_matrix, classification_report
from scikitplot.metrics import plot_confusion_matrix
import pandas as pd
from pprint import pprint
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from scipy.spatial.distance import cosine
from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 import multiprocessing
#       3 from collections import defaultdict
# ----> 4 import matplotlib.pyplot as plt
#       5 import numpy as np
#       6 import yake
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Bibliothèques liées à la classification
# ML
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from scikitplot.metrics import plot_confusion_matrix
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Bibliothèques liées à la classification
#       2 # ML
# ----> 3 from sklearn.datasets import fetch_20newsgroups
#       4 from sklearn.feature_extraction.text import TfidfVectorizer
#       5 from sklearn.naive_bayes import MultinomialNB
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Les SVM et les réseaux de neurones
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#Intégration de BERT et RoBERTa pour une analyse de sentiment plus fine
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Les SVM et les réseaux de neurones
# ----> 2 from sklearn.feature_extraction.text import TfidfVectorizer
#       3 from sklearn.pipeline import Pipeline
#       4 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ##Préparation du Corpus:
#
# 1. Nettoyage et Prétraitement:
#    Utilisation de la biblioteque nltk pour la tokenisation, la lemmatisation et la suppression des stop words.
# Emploi des expressions régulières (module re) pour nettoyer le texte de caractères spéciaux ou de bruit.

# %%
2. Vectorisation:
Conversio des textes en représentations numériques à l'aide de TfidfVectorizer. 
Cette technique pondère les mots en fonction de leur importance dans le document et dans le corpus entier.

# %% [markdown]
# ##Classification:##
#
# 1. Définition des Classes:
# Définition des classes pertinentes pour l´analyse, par exemple :
# Rôles des femmes (mère, professionnelle, victime, etc.)
# Stéréotypes de genre
# Thèmes liés aux femmes (égalité, féminisme, violences faites aux femmes)
# Création d´un jeu de données annoté pour entraîner le modèle.

# %% [markdown]
# ##Détection du genre dans un corpus de journaux : Approche détaillée##
# IdentifiCaction des stéréotypes de genre, les rôles attribués aux femmes et aux hommes, ainsi que les biais linguistiques.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC

# ... (prétraitement du corpus)

# Vectorisation
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)

# Création des labels de genre (0 pour féminin, 1 pour masculin)
y = [0 if 'femme' in text else 1 for text in corpus]

# Division en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Entraînement du modèle SVM
clf = SVC()
clf.fit(X_train, y_train)

# Évaluation du modèle
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))

# %% [markdown]
# ##Analyse Diachronique##
# Objectif: Étudier l'évolution des thèmes et du sentiment liés aux femmes au fil du temps avec spaCy et TextBlob):

# %%
# Fonction pour l'analyse de sentiment et l'extraction d'entités
def analyze_text(text):
    blob = TextBlob(text)
    sentiment = blob.sentiment.polarity
    # Utiliser spaCy pour extraire des entités, des dépendances, etc.
    doc = nlp(text)
    entities = [ent.text for ent in doc.ents]
    return sentiment, entities

# %%
# Appliquer la fonction à chaque texte et créer de nouvelles colonnes
df['sentiment'] = df['text'].apply(lambda x: analyze_text(x)[0])
df['entities'] = df['text'].apply(lambda x: analyze_text(x)[1])

# %%
# Grouper par année et calculer les moyennes de sentiment
df_grouped = df.groupby('date').mean()

# %%
# Visualiser l'évolution du sentiment dans le temps
df_grouped.plot(y='sentiment')

# %% [markdown]
# ##Analyse Comparative##
# Objectif: Comparer les représentations des femmes dans différents médias ou pays avec spaCy et scikit-learn.

# %%
# Vectoriser les textes et réduire la dimensionnalité avec PCA
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X)

# %%
# Visualiser les résultats avec un scatter plot
import matplotlib.pyplot as plt
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=df['source'])

# %%
##Deep Learning##
Objectif: Utilisation des modèles de deep learning pour des tâches plus complexes.

Exemples de tâches et modèles:

Classification fine-grained:
Classifier les textes en sous-catégories plus spécifiques (e.g., types de discrimination, rôles spécifiques des femmes).
Utiliser des modèles comme les réseaux de neurones convolutifs (CNN) ou les réseaux de neurones récurrents (RNN).
Génération de texte:
Générer du texte réaliste sur des sujets liés aux femmes.
Utiliser des modèles comme les GAN ou les modèles de langage pré-entraînés (GPT-3).
Script Python (exemple avec TensorFlow et Keras):

# %%
# ... (tokenisation, padding)
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim),
    LSTM(units=64),
    Dense(num_classes, activation='softmax')
])

# %%
# Compilation et entraînement du modèle
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=32)

# %% [markdown]
# ##Approfondissement de l'Analyse avec des Modèles de Langage Avancés et des Techniques de Visualisation##
# Les modèles de langage de type BERT (Bidirectional Encoder Representations from Transformers) et RoBERTa (Robustly Optimized BERT approach) ont révolutionné le domaine du traitement du langage naturel. Ils sont particulièrement adaptés à des tâches comme l'analyse de sentiment car ils capturent les contextes linguistiques de manière très fine.

# %% [markdown]
# classifier = pipeline("sentiment-analysis")
# result = classifier("Je suis très heureux aujourd'hui.")
# print(result)

# %%
from gensim.models import Word2Vec

# Entraîner un modèle Word2Vec sur votre corpus
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)

# Comparer la similarité entre des mots
print(model.similarity('homme', 'fort'))
print(model.similarity('femme', 'sensible'))
